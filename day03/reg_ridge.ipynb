# %%
import pandas as pd 
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_csv("./data.csv",index_col=False)

# %%
df.columns = ['x1','x2','y']

# %%
X1 = np.array(df['x1'])
X2 = np.array(df['x2'])
y = np.array(df['y'])

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(X1,X2,y)
# ax.plot3D(X1,X2,y,c=y, cmap='viridis', linewidth=0.5)
# ax = Axes3D(fig)
# Axes3D.plot(X1,X2)
